# %% [markdown]
# #Analysis of Health and Lifestyle Metrics
# ##In this comprehensive analysis, I investigate the interplay between various health and lifestyle indicators. The examination analyzes stress levels, sleeping patterns, physical activity, occupation, and other important lifestyle metrics. Rigorous data cleansing procedures were employed to correct any formatting discrepancies. The analysis yielded statistically significant correlations between sleep quality and duration, as well as occupation and stress levels, alongside occupation and sleep duration. This analysis was completed using RStudio.

# %%
library(dplyr)
library(ggplot2)
library(tidyverse)
library(corrplot)
library(caret)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.0
# ✔ readr     2.1.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# corrplot 0.92 loaded
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
#
# The following object is masked from ‘package:httr’:
#
#     progress

# %%
library(readr)
df <- read_csv("/kaggle/input/sleep-health-and-lifestyle-dataset/Sleep_health_and_lifestyle_dataset.csv")
head(df)
# Out:
# Rows: 374 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): Gender, Occupation, BMI Category, Blood Pressure, Sleep Disorder
# dbl (8): Person ID, Age, Sleep Duration, Quality of Sleep, Physical Activity...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Person ID Gender Age Occupation           Sleep Duration Quality of Sleep
# 1 1         Male   27  Software Engineer    6.1            6
# 2 2         Male   28  Doctor               6.2            6
# 3 3         Male   28  Doctor               6.2            6
# 4 4         Male   28  Sales Representative 5.9            4
# 5 5         Male   28  Sales Representative 5.9            4
# 6 6         Male   28  Software Engineer    5.9            4
#   Physical Activity Level Stress Level BMI Category Blood Pressure Heart Rate
# 1 42                      6            Overweight   126/83         77
# 2 60                      8            Normal       125/80         75
# 3 60                      8            Normal       125/80         75
# 4 30                      8            Obese        140/90         85
# 5 30                      8            Obese        140/90         85
# 6 30                      8            Obese        140/90         85
#   Daily Steps Sleep Disorder
# 1  4200       None
# 2 10000       None
# 3 10000       None
# 4  3000       Sleep Apnea
# 5  3000       Sleep Apnea
# 6  3000       Insomnia

# %% [markdown]
# Checking for missing values

# %%
colSums(is.na(df))
# Out:
#               Person ID                  Gender                     Age
#                       0                       0                       0
#              Occupation          Sleep Duration        Quality of Sleep
#                       0                       0                       0
# Physical Activity Level            Stress Level            BMI Category
#                       0                       0                       0
#          Blood Pressure              Heart Rate             Daily Steps
#                       0                       0                       0
#          Sleep Disorder
#                       0

# %% [markdown]
# Formatting aliases

# %%
df$Occupation <- gsub("Sales Representative", "salesperson", df$Occupation)

# %%
df$Occupation <- gsub("salesperson", "Salesperson", df$Occupation)

# %%
ggplot(df, aes(x = Gender, fill=Gender)) +
  geom_bar() +
  labs(y = "Count") +
  geom_text(aes(label = ..count..), stat = "count", vjust = 1.5, colour = "white") +
  scale_fill_manual(values=c("#9999CC", "#66CC99"))
# Out:
# Warning message:
# “The dot-dot notation (`..count..`) was deprecated in ggplot2 3.4.0.
# ℹ Please use `after_stat(count)` instead.”

# %%
ggplot(df, aes(x = Occupation, fill=Occupation)) +
  geom_bar() +
  labs(y = "Count") +
  theme(axis.text.x=element_text(size=10, angle=45,hjust=0.95))

# %%
ggplot(df, aes(x = Occupation, fill=Occupation)) +
  geom_bar() +
  labs(y = "Count") +
  theme(axis.text.x=element_text(size=7, angle=90,hjust=0.95)) +
  facet_wrap(vars(Gender))

# %% [markdown]
# ##The data included 374 participants, 185 females and 189 males. Looking at the occupation by gender showed interesting patterns. Females were more likely to be accountants, nurses, and teachers, while males were more likely to be doctors, lawyers, and salespeople.

# %%
set.seed(42)
#Here I create a correlation matrix with all the quantitative variables
cor(df[c(3, 5, 6, 7, 8, 11, 12)])
# Out:
#                         Age        Sleep Duration Quality of Sleep
# Age                      1.0000000  0.34470936     0.47373388
# Sleep Duration           0.3447094  1.00000000     0.88321300
# Quality of Sleep         0.4737339  0.88321300     1.00000000
# Physical Activity Level  0.1789927  0.21236031     0.19289645
# Stress Level            -0.4223445 -0.81102303    -0.89875203
# Heart Rate              -0.2256062 -0.51645489    -0.65986473
# Daily Steps              0.0579734 -0.03953254     0.01679141
#                         Physical Activity Level Stress Level Heart Rate
# Age                      0.17899272             -0.42234448  -0.22560619
# Sleep Duration           0.21236031             -0.81102303  -0.51645489
# Quality of Sleep         0.19289645             -0.89875203  -0.65986473
# Physical Activity Level  1.00000000             -0.03413446   0.13697098
# Stress Level            -0.03413446              1.00000000   0.67002646
# Heart Rate               0.13697098              0.67002646   1.00000000
# Daily Steps              0.77272305              0.18682895  -0.03030858
#                         Daily Steps
# Age                      0.05797340
# Sleep Duration          -0.03953254
# Quality of Sleep         0.01679141
# Physical Activity Level  0.77272305
# Stress Level             0.18682895
# Heart Rate              -0.03030858
# Daily Steps              1.00000000

# %% [markdown]
# ##Here we can see which variables had the strongest correlations. Quality of sleep and sleep duration and quality of sleep and stress level had a very strong correlation.

# %%
ggplot() + 
  geom_point(data = df, mapping = aes(x = `Quality of Sleep`, y = `Sleep Duration`)) +
  geom_smooth(data = df, mapping = aes(x = `Quality of Sleep`, y = `Sleep Duration`)) +
  ggtitle("Quality of Sleep vs Sleep Duration") +
  theme(plot.title = element_text(hjust = 0.5))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 7”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 7”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  0”

# %%
ggplot() + 
  geom_point(data = df, mapping = aes(x = `Stress Level`, y = `Sleep Duration`)) +
  geom_smooth(data = df, mapping = aes(x = `Stress Level`, y = `Sleep Duration`)) +
  ggtitle("Quality of Sleep vs Sleep Duration")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'

# %%
ggplot() + 
  geom_point(data = df, mapping = aes(x = `Physical Activity Level`, y = `Sleep Duration`)) +
  geom_smooth(data = df, mapping = aes(x = `Physical Activity Level`, y = `Sleep Duration`)) +
  ggtitle("Physical Activity Level vs Sleep Duration")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'

# %%
ggplot() + 
  geom_point(data = df, mapping = aes(x = `Physical Activity Level`, y = `Daily Steps`)) +
  geom_smooth(data = df, mapping = aes(x = `Physical Activity Level`, y = `Daily Steps`)) +
  ggtitle("Physical Activity Level vs Sleep Duration")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'

# %% [markdown]
# #Physical activity and daily steps had a strong correlation of 0.77

# %%
ggplot() + 
  geom_boxplot(data = df, mapping = aes(y = `Daily Steps`, x = Occupation)) +
  theme(axis.text.x=element_text(size=10, angle=45,hjust=0.95))
##Nurses took the most daily steps

# %%
mean(df$`Daily Steps`)
# Out:
# [1] 6816.845

# %% [markdown]
# ##The participants averaged 6817 daily steps

# %%
ggplot() + 
  geom_boxplot(data = df, mapping = aes(y = `Daily Steps`, x = Gender))

# %%
ggplot() + 
  geom_point(data = df, mapping = aes(x = `Daily Steps`, y = `Sleep Duration`)) +
  geom_smooth(data = df, mapping = aes(x = `Daily Steps`, y = `Sleep Duration`)) +
  ggtitle("Daily Steps vs Sleep Duration")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'

# %%
ggplot() + 
  geom_point(data = df, mapping = aes(x = `Heart Rate`, y = `Stress Level`)) +
  geom_smooth(data = df, mapping = aes(x = `Heart Rate`, y = `Stress Level`)) + 
  ggtitle("Heart Rate vs Stress Level")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'

# %% [markdown]
# #Sleep duration had a strong negative effect on stress level
# #People who had more sleep had a lower stress level, while
# #people who got less sleep had a much higher stress level.

# %%
aggregated_data <- df %>%
  group_by(Occupation, Gender) %>%
  summarize(Sum_Stress_Level = sum(`Stress Level`, na.rm = TRUE), .groups = "drop")

ggplot(aggregated_data, aes(x = Occupation, y = Sum_Stress_Level, fill = Gender)) +
  geom_bar(stat = "identity", position = "stack") +
  labs(
    x = "Occupation",
    y = "Sum of Stress Levels",
    fill = "Gender",
    title = "Sum of Stress Levels by Gender and Occupation"
  ) +
  theme(
    axis.text.x = element_text(size = 10, angle = 45, hjust = 0.95),
    plot.title = element_text(hjust = 0.5)
  )

# %% [markdown]
# ##We can see interesting patterns by looking at the stress levels of the different positions. Doctors, Nurses, and Salespeople had the highest stress levels.

# %%
ggplot(df, aes(x = `Stress Level`, fill=as.factor(`Stress Level`))) + geom_density() +
  guides(fill=guide_legend(title="Stress Level")) +
  labs(y = "Density") +
  scale_fill_brewer(palette="Accent") +
  facet_wrap(vars(Gender)) +
  ggtitle("Distribution of Heart Rate vs Stress Level")

# %%
ggplot(df, aes(x = `Stress Level`, fill=as.factor(`Stress Level`))) + geom_bar() +
  guides(fill=guide_legend(title="Stress Level")) +
  labs(y = "Count") +
  scale_fill_brewer(palette="Accent") +
  facet_wrap(vars(Gender)) +
  ggtitle("Distribution of Heart Rate vs Stress Level")

# %%
numeric_df <- df %>% select(where(is.numeric))

# %%
numeric_df <- numeric_df %>%
  select(-`Person ID`)

# %%
numeric_df
# Out:
#     Age Sleep Duration Quality of Sleep Physical Activity Level Stress Level
# 1   27  6.1            6                42                      6
# 2   28  6.2            6                60                      8
# 3   28  6.2            6                60                      8
# 4   28  5.9            4                30                      8
# 5   28  5.9            4                30                      8
# 6   28  5.9            4                30                      8
# 7   29  6.3            6                40                      7
# 8   29  7.8            7                75                      6
# 9   29  7.8            7                75                      6
# 10  29  7.8            7                75                      6
# 11  29  6.1            6                30                      8
# 12  29  7.8            7                75                      6
# 13  29  6.1            6                30                      8
# 14  29  6.0            6                30                      8
# 15  29  6.0            6                30                      8
# 16  29  6.0            6                30                      8
# 17  29  6.5            5                40                      7
# 18  29  6.0            6                30                      8
# 19  29  6.5            5                40                      7
# 20  30  7.6            7                75                      6
# 21  30  7.7            7                75                      6
# 22  30  7.7            7                75                      6
# 23  30  7.7            7                75                      6
# 24  30  7.7            7                75                      6
# 25  30  7.8            7                75                      6
# 26  30  7.9            7                75                      6
# 27  30  7.8            7                75                      6
# 28  30  7.9            7                75                      6
# 29  30  7.9            7                75                      6
# 30  30  7.9            7                75                      6
# ⋮   ⋮   ⋮              ⋮                ⋮                       ⋮
# 345 57  8.2            9                75                      3
# 346 57  8.2            9                75                      3
# 347 57  8.2            9                75                      3
# 348 57  8.2            9                75                      3
# 349 57  8.2            9                75                      3
# 350 57  8.1            9                75                      3
# 351 57  8.1            9                75                      3
# 352 57  8.1            9                75                      3
# 353 58  8.0            9                75                      3
# 354 58  8.0            9                75                      3
# 355 58  8.0            9                75                      3
# 356 58  8.0            9                75                      3
# 357 58  8.0            9                75                      3
# 358 58  8.0            9                75                      3
# 359 59  8.0            9                75                      3
# 360 59  8.1            9                75                      3
# 361 59  8.2            9                75                      3
# 362 59  8.2            9                75                      3
# 363 59  8.2            9                75                      3
# 364 59  8.2            9                75                      3
# 365 59  8.0            9                75                      3
# 366 59  8.0            9                75                      3
# 367 59  8.1            9                75                      3
# 368 59  8.0            9                75                      3
# 369 59  8.1            9                75                      3
# 370 59  8.1            9                75                      3
# 371 59  8.0            9                75                      3
# 372 59  8.1            9                75                      3
# 373 59  8.1            9                75                      3
# 374 59  8.1            9                75                      3
#     Heart Rate Daily Steps
# 1   77          4200
# 2   75         10000
# 3   75         10000
# 4   85          3000
# 5   85          3000
# 6   85          3000
# 7   82          3500
# 8   70          8000
# 9   70          8000
# 10  70          8000
# 11  70          8000
# 12  70          8000
# 13  70          8000
# 14  70          8000
# 15  70          8000
# 16  70          8000
# 17  80          4000
# 18  70          8000
# 19  80          4000
# 20  70          8000
# 21  70          8000
# 22  70          8000
# 23  70          8000
# 24  70          8000
# 25  70          8000
# 26  70          8000
# 27  70          8000
# 28  70          8000
# 29  70          8000
# 30  70          8000
# ⋮   ⋮          ⋮
# 345 68         7000
# 346 68         7000
# 347 68         7000
# 348 68         7000
# 349 68         7000
# 350 68         7000
# 351 68         7000
# 352 68         7000
# 353 68         7000
# 354 68         7000
# 355 68         7000
# 356 68         7000
# 357 68         7000
# 358 68         7000
# 359 68         7000
# 360 68         7000
# 361 68         7000
# 362 68         7000
# 363 68         7000
# 364 68         7000
# 365 68         7000
# 366 68         7000
# 367 68         7000
# 368 68         7000
# 369 68         7000
# 370 68         7000
# 371 68         7000
# 372 68         7000
# 373 68         7000
# 374 68         7000

# %%
set.seed(42) 
train_index <- createDataPartition(numeric_df$`Stress Level`, p = 0.8, list = FALSE)
train_data <- numeric_df[train_index, ]
test_data <- numeric_df[-train_index, ]

# %%
model <- train(
  `Stress Level` ~ .,  # Predict Stress Level using all other features
  data = train_data,
  method = "lm",  # Linear Regression
  trControl = trainControl(method = "cv", number = 5)  # 5-fold cross-validation
)

# %%
summary(model$finalModel)
# Out:
# Call:
# lm(formula = .outcome ~ ., data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.38649 -0.13345  0.08913  0.17073  1.58801
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      5.168e+00  1.406e+00   3.676 0.000282 ***
# Age                             -3.620e-03  4.828e-03  -0.750 0.453957
# `\\`Sleep Duration\\``          -4.266e-02  1.024e-01  -0.417 0.677266
# `\\`Quality of Sleep\\``        -1.045e+00  8.243e-02 -12.672  < 2e-16 ***
# `\\`Physical Activity Level\\`` -1.732e-02  3.582e-03  -4.834 2.17e-06 ***
# `\\`Heart Rate\\``               9.494e-02  1.449e-02   6.552 2.55e-10 ***
# `\\`Daily Steps\\``              3.930e-04  4.282e-05   9.178  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6151 on 293 degrees of freedom
# Multiple R-squared:  0.8833,	Adjusted R-squared:  0.8809
# F-statistic: 369.6 on 6 and 293 DF,  p-value: < 2.2e-16

# %%
predictions <- predict(model, newdata = test_data)

# %%
actuals <- test_data$`Stress Level`
rmse <- sqrt(mean((predictions - actuals)^2)) 
r2 <- cor(predictions, actuals)^2  

cat("Test RMSE:", rmse, "\n")
cat("Test R-squared:", r2, "\n")
# Out:
# Test RMSE: 0.715373
# Test R-squared: 0.8319883

# %%
ggplot(data = data.frame(Actual = actuals, Predicted = predictions), aes(x = Actual, y = Predicted)) +
  geom_point(alpha = 0.7) +
  geom_abline(intercept = 0, slope = 1, color = "red", linetype = "dashed") +
  labs(title = "Predicted vs Actual Stress Levels", x = "Actual Stress Levels", y = "Predicted Stress Levels") +
  theme_minimal()

# %%
train_predictions <- predict(model, newdata = train_data)
train_actuals <- train_data$`Stress Level`

# %%
train_rmse <- sqrt(mean((train_predictions - train_actuals)^2))
train_r2 <- cor(train_predictions, train_actuals)^2

# %%
test_predictions <- predict(model, newdata = test_data)
test_actuals <- test_data$`Stress Level`

# %%
test_rmse <- sqrt(mean((test_predictions - test_actuals)^2))
test_r2 <- cor(test_predictions, test_actuals)^2

# %%
avg_r2 <- (train_r2 + test_r2) / 2

# %%
cat("Model Scores", "\n")
cat("Training RMSE:", train_rmse, "\n")
cat("Training R-squared:", train_r2, "\n")
cat("Test RMSE:", test_rmse, "\n")
cat("Test R-squared:", test_r2, "\n")
cat("Average R-squared:", avg_r2, "\n")
# Out:
# Model Scores
# Training RMSE: 0.6078658
# Training R-squared: 0.8833069
# Test RMSE: 0.715373
# Test R-squared: 0.8319883
# Average R-squared: 0.8576476

# %%
combined_data <- data.frame(
  Actual = c(train_actuals, test_actuals),
  Predicted = c(train_predictions, test_predictions),
  Set = c(rep("Training", length(train_actuals)), rep("Test", length(test_actuals)))
)

ggplot(data = combined_data, aes(x = Actual, y = Predicted, color = Set)) +
  geom_point(alpha = 0.7) +
  geom_abline(intercept = 0, slope = 1, color = "red", linetype = "dashed") +
  labs(
    title = "Predicted vs Actual Stress Levels (Training and Test Sets)",
    x = "Actual Stress Levels",
    y = "Predicted Stress Levels"
  ) +
  scale_color_manual(values = c("Training" = "blue", "Test" = "green")) +
  theme_minimal()

# %% [markdown]
# The model performs relatively well on both the training and the test sets, with an average R-squared score of 0.857. The high R-squared values for both training and test sets indicate the model captures most of the variability in the target variable, stress levels. There is no evidence of severe overfitting or underfitting based on these scores. The model proves efficacy in predicting stress levels based on the other health and lifestyle metrics included in the dataset.
